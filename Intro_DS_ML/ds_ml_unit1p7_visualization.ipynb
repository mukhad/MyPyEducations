# %% [markdown]
# ## 1.7 Визуализация

# %%
# %matplotlib inline
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %%
sp = pd.read_csv('data/StudentsPerformance.csv')
sp.columns = sp.columns.str.replace(' ','_')
sp.columns = sp.columns.str.replace('/','_')
sp.head()
# Out:
#    gender race_ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
sp.math_score.hist()
# Out:
# <AxesSubplot:>

# %%
sp.plot.scatter(x = 'math_score', y = 'reading_score')
# Out:
# <AxesSubplot:xlabel='math_score', ylabel='reading_score'>

# %%
gr = sns.lmplot(x = 'math_score', y = 'reading_score', hue = 'gender', data = sp, fit_reg = False )
gr.set_xlabels('math_score')

# %%
df = pd.read_csv('data/income.csv')
df.head()
# Out:
#             income
# 2018-11-30      20
# 2018-12-31      60
# 2019-01-31     180
# 2019-02-28     380
# 2019-03-31     660

# %%
dt=pd.read_csv('data/dataset_209770_6.txt', sep = ' ')
dt
# Out:
#                x            y
# 0    1381.450854   497.254222
# 1     300.664997   599.684711
# 2     994.485941   404.275584
# 3     489.978966   205.270058
# 4    1402.615052   507.214597
# ..           ...          ...
# 105   704.439772   700.509663
# 106   188.240105   999.023747
# 107  1292.814996  1400.214130
# 108   205.117939   993.729069
# 109  1503.728550  1309.881985
#
# [110 rows x 2 columns]

# %%
sns.lmplot(x = 'x', y = 'y',data= dt)

# %%
sns.scatterplot(dt.iloc[:, 0], dt.iloc[:, 1])
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>

# %%
gm=pd.read_csv('data/genome_matrix.csv', sep = ',',index_col=0)
gm
# Out:
#           species0  species1  species2  species3  species4
# species0  0.536029  0.920292  0.679708  0.840606  0.430842
# species1  0.920292  0.862417  0.887593  0.769754  0.203214
# species2  0.679708  0.887593  0.595156  0.003435  0.096052
# species3  0.840606  0.769754  0.003435  0.458870  0.029251
# species4  0.430842  0.203214  0.096052  0.029251  0.642109

# %%
#gm = gm.drop(['Unnamed: 0'],axis =1)
g = sns.heatmap(gm,cmap="viridis") 
g.xaxis.set_ticks_position('top')
g.xaxis.set_tick_params(rotation=90)

# %%
dota = pd.read_csv('data/dota_hero_stats.csv', sep = ',')
dota
# Out:
#      Unnamed: 0 attack_type   id  legs  localized_name  \
# 0             0       Melee    1     2       Anti-Mage
# 1             1       Melee    2     2             Axe
# 2             2      Ranged    3     4            Bane
# 3             3       Melee    4     2     Bloodseeker
# 4             4      Ranged    5     2  Crystal Maiden
# ..          ...         ...  ...   ...             ...
# 112         112       Melee  114     2     Monkey King
# 113         113      Ranged  119     2     Dark Willow
# 114         114       Melee  120     2       Pangolier
# 115         115      Ranged  121     2      Grimstroke
# 116         116       Melee  129     2            Mars
#
#                              name primary_attr  \
# 0          npc_dota_hero_antimage          agi
# 1               npc_dota_hero_axe          str
# 2              npc_dota_hero_bane          int
# 3       npc_dota_hero_bloodseeker          agi
# 4    npc_dota_hero_crystal_maiden          int
# ...

# %%
#Гистограмма, отражающая скольким героям сколько ролей приписывается в dota
#dota.roles.str.split(',').str.len().value_counts()
ota.roles.str.split(",").str.len().hist()
# Out:
# <AxesSubplot:>

# %%
#скачайте датасэт со значениями параметров ирисов, постройте их распределения
iris = pd.read_csv('data/iris.csv', sep = ',', index_col=0)
iris
# Out:
#      sepal length  sepal width  petal length  petal width  species
# 0             5.1          3.5           1.4          0.2        0
# 1             4.9          3.0           1.4          0.2        0
# 2             4.7          3.2           1.3          0.2        0
# 3             4.6          3.1           1.5          0.2        0
# 4             5.0          3.6           1.4          0.2        0
# ..            ...          ...           ...          ...      ...
# 145           6.7          3.0           5.2          2.3        2
# 146           6.3          2.5           5.0          1.9        2
# 147           6.5          3.0           5.2          2.0        2
# 148           6.2          3.4           5.4          2.3        2
# 149           5.9          3.0           5.1          1.8        2
#
# [150 rows x 5 columns]

# %%
for col in iris:    
    sns.kdeplot(iris[col])
    #sns.distplot(iris[col])

# %%
#распределение длины лепестков ирисов из предыдущего датасэта с помощью violin плота
sns.violinplot(x=iris['petal length'], orient='v')
# Out:
# <AxesSubplot:ylabel='petal length'>

# %%
iris['petal length'].describe()
# Out:
# count    150.000000
# mean       3.758667
# std        1.764420
# min        1.000000
# 25%        1.600000
# 50%        4.350000
# 75%        5.100000
# max        6.900000
# Name: petal length, dtype: float64

# %%
# pairplot, отражающий зависимость пар переменных друг от друга, а также распределение каждой из переменных
sns.pairplot(iris, hue='species')
