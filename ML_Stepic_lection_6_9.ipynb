# %%
TN = 25 #     0  1
FN = 20 # 0  TN  FN
FP = 10 # 1  FP  TP
TP = 15 

accuracy = (TN+TP)/(TN + TP + FN + FP)

precision = TP / (TP+FP)

recall = TP / (TP + FN)

print(accuracy)
print(precision)
print(recall)
# Out:
# 0.5714285714285714
# 0.6
# 0.42857142857142855

# %%
TN = 0  #     0  1
FN = 0  # 0  TN  FN
FP = 20 # 1  FP  TP
TP = 30 

accuracy = (TN+TP)/(TN + TP + FN + FP)

precision = TP / (TP+FP)

recall = TP / (TP + FN)

print(accuracy)
print(precision)
print(recall)
# Out:
# 0.6
# 0.6
# 1.0

# %% [markdown]
# # ![image.png](attachment:image.png)

# %%
#Gini(P1)=3/5*1/3*1/2+2/5*1/2*1/2=0,20
g1 = (3/5)*(1/3)*(2/3) + (2/5)*(1/2)*(1/2)

g2 = (0/5)*(0)*(0)  + (5/5)*(2/5)*(3/5)
g3 = (3/5)*(0)*(3/3) + (2/5)*(2/2)*(0)

# %%
print(g1)
print(g2)
print(g3)
# Out:
# 0.2333333333333333
# 0.24
# 0.0

# %%
r = 51*1440*4*8*6
s = 14100502
print(s - r)

print(r)
# Out:
# 22
# 14100480

# %%
4+(5+4)*2
# Out:
# 22

# %%
a = 0.6
b = 0.2
#L = (1-2*a+b)^2+(1-a+b)^2+(1-b)^2+(1-a-b)^2+(1-2*a-b)^2
print(-b/a)
# Out:
# -0.33333333333333337

# %% [raw]
# Django: Практика создания Web-сайтов на Python
# Скрапинг веб-сайтов с помощью Python
#
# Машинное обучение
# Алгоритмы: разработка и применение. Классика Computers Science
# Unity в действии. Мультиплатформенная разработка на C#

# %%
# lection 9 test 1
p = list(0 for i in range(0,4))
# lection 9 test 1
А = 0.5  # {выпало нечетное число}       равна  0,5     1 3 5
В = 0.33 #{выпало число строго больше 4} равна  0,33    5 6 
С = 0.83 #{выпало число не меньше 2}     равна  0,83    2 3 4 5 6
# Pr(A|B)= 
# Pr(B|A)=  
# Pr(A|C)=  
# Pr(C|A)=
p[0] = 1/2
p[1] = 1/3
p[2] = 2/5
p[3] = 2/3
 

for i in p:
    print("{0:6.2f}".format(i))
# Out:
#   0.50
#   0.33
#   0.40
#   0.67

# %%
# lection 9 test 2
k = 0.7 * 0.1 + (1-0.7) * 0.5
p = 0.1 * 0.7 / 0.22
print("{0:6.2f}".format(k))
print("{0:6.2f}".format(p))
# Out:
#   0.22
#   0.32

# %%
7/9
# Out:
# 0.7777777777777778
